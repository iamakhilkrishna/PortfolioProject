# %%
df= pd.read.csv("C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\Divvy_Trips_2018_Q1.csv")
# Out:
#   Cell In[2], line 1
#     df= pd.read.csv("C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\Divvy_Trips_2018_Q1.csv")
#                                                                                                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv(r"C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\Divvy_Trips_2018_Q1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\Divvy_Trips_2018_Q1.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\Divvy_Trips_2018_Q1.csv")

# %%
df.head()
# Out:
#     trip_id       start_time         end_time  bike_id trip_duration  \
# 0  17536702  2018-01-01 0:12  2018-01-01 0:17     3304           323
# 1  17536703  2018-01-01 0:41  2018-01-01 0:47     5367           377
# 2  17536704  2018-01-01 0:44  2018-01-01 1:33     4599      2,904.00
# 3  17536705  2018-01-01 0:53  2018-01-01 1:05     2302           747
# 4  17536706  2018-01-01 0:53  2018-01-01 0:56     3696           183
#
#    from_station_id            from_station_name  to_station_id  \
# 0               69       Damen Ave & Pierce Ave            159
# 1              253  Winthrop Ave & Lawrence Ave            325
# 2               98   LaSalle St & Washington St            509
# 3              125         Rush St & Hubbard St            364
# 4              129    Blue Island Ave & 18th St            205
#
#                   to_station_name   user_type gender  birth_year ride_length  \
# 0       Claremont Ave & Hirsch St  Subscriber   Male      1988.0    00:05:23
# ...

# %%
# Standardize trip_duration by removing commas and converting to numeric
df['trip_duration'] = df['trip_duration'].str.replace(',', '').astype(float)

# %%
print(df.dtypes)
# Out:
# trip_id                int64
# start_time            object
# end_time              object
# bike_id                int64
# trip_duration         object
# from_station_id        int64
# from_station_name     object
# to_station_id          int64
# to_station_name       object
# user_type             object
# gender                object
# birth_year           float64
# ride_length           object
# weekday                int64
# weekdays              object
# dtype: object

# %%
# Handle missing values - assuming we assign 'Unknown' to missing user types
df['user_type'].fillna('Unknown', inplace=True)

# %%
df.head()
# Out:
#     trip_id          start_time            end_time  bike_id  trip_duration  \
# 0  17536702 2018-01-01 00:12:00 2018-01-01 00:17:00     3304          323.0
# 1  17536703 2018-01-01 00:41:00 2018-01-01 00:47:00     5367          377.0
# 2  17536704 2018-01-01 00:44:00 2018-01-01 01:33:00     4599         2904.0
# 3  17536705 2018-01-01 00:53:00 2018-01-01 01:05:00     2302          747.0
# 4  17536706 2018-01-01 00:53:00 2018-01-01 00:56:00     3696          183.0
#
#    from_station_id            from_station_name  to_station_id  \
# 0               69       Damen Ave & Pierce Ave            159
# 1              253  Winthrop Ave & Lawrence Ave            325
# 2               98   LaSalle St & Washington St            509
# 3              125         Rush St & Hubbard St            364
# 4              129    Blue Island Ave & 18th St            205
#
#                   to_station_name   user_type gender  birth_year  ride_length  \
# ...

# %%
# Handle missing values - assuming we assign 'N/A' to missing gender
df['gender'].fillna('N/A', inplace=True)

# %%
# Convert ride_length to total seconds for easier analysis
def convert_to_seconds(time_str):
    h, m, s = time_str.split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)

df['ride_length'] = df['ride_length'].apply(convert_to_seconds)

# %%
# Convert birth_year to integer, handling NaN values by replacing them with a sentinel value or dropping them
df['birth_year'] = df['birth_year'].fillna(0).astype(int)  # or df.dropna(subset=['birth_year'])

# %%
df.to_csv('C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\cleansed_Divvy_Trips_2018_Q1.csv', index=False)
# Out:
#   Cell In[31], line 1
#     df.to_csv('C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\cleansed_Divvy_Trips_2018_Q1.csv', index=False)
#                                                                                                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df.to_csv(r'C:\Users\mavur\OneDrive\Desktop\BikeShare Data\2018\cleansed_Divvy_Trips_2018_Q1.csv', index=False)

# %%
df.head()
# Out:
#     trip_id          start_time            end_time  bike_id  trip_duration  \
# 0  17536702 2018-01-01 00:12:00 2018-01-01 00:17:00     3304          323.0
# 1  17536703 2018-01-01 00:41:00 2018-01-01 00:47:00     5367          377.0
# 2  17536704 2018-01-01 00:44:00 2018-01-01 01:33:00     4599         2904.0
# 3  17536705 2018-01-01 00:53:00 2018-01-01 01:05:00     2302          747.0
# 4  17536706 2018-01-01 00:53:00 2018-01-01 00:56:00     3696          183.0
#
#    from_station_id            from_station_name  to_station_id  \
# 0               69       Damen Ave & Pierce Ave            159
# 1              253  Winthrop Ave & Lawrence Ave            325
# 2               98   LaSalle St & Washington St            509
# 3              125         Rush St & Hubbard St            364
# 4              129    Blue Island Ave & 18th St            205
#
#                   to_station_name   user_type gender  birth_year  ride_length  \
# ...

# %%
# Assuming 'df' is your DataFrame and trip_duration is already in seconds
average_trip_duration = df.groupby('user_type')['trip_duration'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Assuming 'df' is your DataFrame and trip_duration is already in seconds
# ----> 2 average_trip_duration = df.groupby('user_type')['trip_duration'].mean()
#
# NameError: name 'df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17636\725055173.py in ?()
# ----> 1 df.average_trip_duration()
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'average_trip_duration'

# %%
print(average_trip_duration)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(average_trip_duration)
#
# NameError: name 'average_trip_duration' is not defined

# %%
import matplotlib.pyplot as plt

# Assuming average_trip_duration_minutes is a Series with index as user types
average_trip_duration_minutes.plot(kind='bar', color=['blue', 'orange'])

plt.title('Average Trip Duration by User Type')
plt.xlabel('User Type')
plt.ylabel('Average Trip Duration (minutes)')
plt.xticks(rotation=0)  # Rotates the user type labels to be horizontal
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 import matplotlib.pyplot as plt
#       3 # Assuming average_trip_duration_minutes is a Series with index as user types
#       4 average_trip_duration_minutes.plot(kind='bar', color=['blue', 'orange'])
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Convert start_time and end_time to datetime
df['start_time'] = pd.to_datetime(df['start_time'])
df['end_time'] = pd.to_datetime(df['end_time'])

# %%
print(df.dtypes)
# Out:
# trip_id                       int64
# start_time           datetime64[ns]
# end_time             datetime64[ns]
# bike_id                       int64
# trip_duration               float64
# from_station_id               int64
# from_station_name            object
# to_station_id                 int64
# to_station_name              object
# user_type                    object
# gender                       object
# birth_year                  float64
# ride_length                  object
# weekday                       int64
# weekdays                     object
# dtype: object

# %%
# Standardize trip_duration by removing commas and converting to numeric
df['trip_duration'] = df['trip_duration'].str.replace(',', '').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Standardize trip_duration by removing commas and converting to numeric
# ----> 2 df['trip_duration'] = df['trip_duration'].str.replace(',', '').astype(float)
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File C:\Python310\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
df.head(50)
# Out:
#      trip_id          start_time            end_time  bike_id  trip_duration  \
# 0   17536702 2018-01-01 00:12:00 2018-01-01 00:17:00     3304          323.0
# 1   17536703 2018-01-01 00:41:00 2018-01-01 00:47:00     5367          377.0
# 2   17536704 2018-01-01 00:44:00 2018-01-01 01:33:00     4599         2904.0
# 3   17536705 2018-01-01 00:53:00 2018-01-01 01:05:00     2302          747.0
# 4   17536706 2018-01-01 00:53:00 2018-01-01 00:56:00     3696          183.0
# 5   17536707 2018-01-01 00:56:00 2018-01-01 01:00:00     6298          266.0
# 6   17536708 2018-01-01 00:57:00 2018-01-01 01:02:00     1169          314.0
# 7   17536709 2018-01-01 01:00:00 2018-01-01 01:13:00     6351          794.0
# 8   17536710 2018-01-01 01:07:00 2018-01-01 01:31:00     1920         1481.0
# 9   17536711 2018-01-01 01:07:00 2018-01-06 10:04:00     4783       464168.0
# 10  17536712 2018-01-01 01:08:00 2018-01-01 01:31:00     3881         1361.0
# ...

# %%
# Convert ride_length to total seconds for easier analysis
def convert_to_seconds(time_str):
    h, m, s = time_str.split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)

df['ride_length'] = df['ride_length'].apply(convert_to_seconds)

# %%
# Convert birth_year to integer, handling NaN values by replacing them with a sentinel value or dropping them
df['birth_year'] = df['birth_year'].fillna(0).astype(int)  # or df.dropna(subset=['birth_year'])

# %%
print(df.dtypes)
# Out:
# trip_id                       int64
# start_time           datetime64[ns]
# end_time             datetime64[ns]
# bike_id                       int64
# trip_duration               float64
# from_station_id               int64
# from_station_name            object
# to_station_id                 int64
# to_station_name              object
# user_type                    object
# gender                       object
# birth_year                    int32
# ride_length                   int64
# weekday                       int64
# weekdays                     object
# dtype: object

# %%
# Calculate average trip duration for each user type
average_trip_duration = df.groupby('user_type')['trip_duration'].mean()

# %%
print(average_trip_duration)
# Out:
# user_type
# Customer      6233.508666
# Subscriber     716.200251
# Name: trip_duration, dtype: float64

# %%
From this data, we can draw several preliminary insights:

Customer Behavior: Casual riders (Customers) tend to have significantly longer trip durations than Subscribers. This could imply that they use the bike-share service for more leisurely rides or less frequent, but longer, trips.

Subscriber Usage: Subscribers seem to use the service for shorter durations, which could be indicative of regular commutes or routine use with a specific purpose, like running errands or short-distance travel that's part of a daily routine.

This insight can be valuable for the marketing team. For example, since casual riders tend to take longer trips, marketing campaigns aimed at converting them to subscribers could highlight the cost savings of an annual membership for extended use. Conversely, for subscribers, marketing could focus on the convenience and reliability of the service for daily tasks.

The next steps in the EDA could involve looking at the frequency of rides to understand how often these users engage with the service, analyzing peak usage times to determine when they are most likely to ride, and identifying the most common start and end stations to understand their travel patterns better. Visualizations such as histograms and bar charts would be helpful to present these findings.

# %%
# Extract the hour from the start_time to find peak hours
df['start_hour'] = df['start_time'].dt.hour
peak_usage = df.groupby(['start_hour', 'user_type']).size().unstack().idxmax()

# %%
# Find the most common start and end stations for each user type
most_common_start = df.groupby('user_type')['from_station_name'].agg(pd.Series.mode)
most_common_end = df.groupby('user_type')['to_station_name'].agg(pd.Series.mode)

# %%
print(peak_usage)
# Out:
# user_type
# Customer      15
# Subscriber    17
# dtype: int64

# %%
Customers (casual riders) have their peak usage at 3 PM.
Subscribers (annual members) have their peak usage at 5 PM.
Here are some insights based on this information:

Casual Riders' Peak Time: The peak time for Customers suggests that casual riders might be using the bikes for leisure activities or tourism, especially if this peak time is on weekends or coincides with the end of a typical workday.

Subscribers' Peak Time: The peak time for Subscribers being later in the afternoon could imply that these users are possibly commuting home from work or using the bikes for evening errands or activities.

With these insights, the marketing team can consider the following strategies:

Timing for Campaigns: Target marketing campaigns at or around these peak times when users are most active and engaged with the service. For example, in-app notifications or social media ads could be scheduled around these hours.

Promotions: Offer special promotions or incentives during off-peak hours to increase bike usage throughout the day, or partner with local businesses to offer discounts and benefits for bike riders.

Content Strategy: Create content that resonates with the identified behaviors during these peak times, such as highlighting bike routes for leisurely rides in the early afternoon for Customers, or promoting a reliable and fast commute home for Subscribers.

Further analysis could refine these insights, such as breaking down peak usage by day of the week, or looking at the duration and distance of rides during peak hours compared to off-peak hours. This could inform whether these patterns hold true consistently or are subject to variation on weekends versus weekdays.

# %%
print(most_common_start)
# Out:
# user_type
# Customer      Streeter Dr & Grand Ave
# Subscriber        Canal St & Adams St
# Name: from_station_name, dtype: object

# %%
import matplotlib.pyplot as plt

average_trip_duration.plot(kind='bar')
plt.title('Average Trip Duration by User Type')
plt.xlabel('User Type')
plt.ylabel('Average Trip Duration (seconds)')
plt.show()

# %%
peak_usage.plot(kind='line')
plt.title('Peak Usage Hours by User Type')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Trips')
plt.show()

# %%
import pandas as pd

# Assuming df is your DataFrame and it already includes 'start_time' as a datetime column

# Extract the day of the week from the 'start_time' (0=Monday, 6=Sunday)
df['day_of_week'] = df['start_time'].dt.dayofweek

# Extract the hour of the day from the 'start_time'
df['start_hour'] = df['start_time'].dt.hour

# Group by user type and day of the week, then find the most common start hour for each group
peak_hours_by_day = df.groupby(['user_type', 'day_of_week'])['start_hour'].agg(lambda x: x.mode().iloc[0])

# The result will be a Series with a MultiIndex (user_type, day_of_week)
# You can unstack this to get a DataFrame if needed:
peak_hours_by_day_df = peak_hours_by_day.unstack(level='user_type')

# %%
print(peak_hours_by_day_df)
# Out:
# user_type    Customer  Subscriber
# day_of_week
# 0                  16          17
# 1                  16          17
# 2                  15          17
# 3                  16          17
# 4                  15          17
# 5                  16          13
# 6                  14          13

# %%
Here's what we can interpret from this data:

Subscribers:

Have consistent peak usage at 5 PM (17:00 hours) from Monday to Friday, likely aligning with typical workday commuting hours.
On weekends (Saturday and Sunday), their peak usage shifts to 1 PM (13:00 hours), suggesting a pattern of leisure or errand activities that align with typical non-working hours.
Customers:

Show a peak usage at 4 PM (16:00 hours) on Mondays, Tuesdays, Thursdays, and Saturdays, with a slight shift to 3 PM (15:00 hours) on Wednesdays and Fridays.
Sunday shows a different pattern, with peak usage at 2 PM (14:00 hours), indicating a possible preference for early afternoon leisure rides.
Insights and Strategic Implications:
Weekday Strategy for Subscribers:

Since Subscribers tend to use the service at the end of the conventional workday, strategies could focus on positioning Cyclistic as a reliable commuting option, offering incentives that make the regular commute more appealing.
Weekend Strategy for Subscribers:

With the shift to earlier hours on weekends, marketing can pivot to promoting leisure and family activities that could be enhanced with a bike ride, such as visiting parks or attractions.
Customer Engagement:

For casual riders, the later afternoon peak times suggest that these users may be more leisure-oriented. Marketing campaigns could highlight leisurely aspects of biking, such as exploring neighborhoods, riding for fitness, or enjoying the outdoors.
Targeted Offers:

Special weekend promotions could be targeted at Subscribers to encourage increased usage during these off-peak times, such as partner discounts at popular destinations or events.
Customer Conversion:

Understanding that Customers use the service consistently in the mid to late afternoon, targeted messaging about the benefits of membership could be delivered during these hours, perhaps highlighting cost savings for frequent riders.
Digital Media Utilization:

Digital media campaigns could be timed to coincide with these peak hours, using platforms where users are likely to be active before deciding to take a ride.
Service Optimization:

Operations could ensure bike and dock availability is optimized for these peak times to maintain a high level of service that meets rider demand.
By tailoring marketing messages and operational logistics to these patterns, Cyclistic can better engage with both user types at the times they are most likely to ride, potentially increasing overall satisfaction and converting more casual riders to annual members.
# Out:
#   Cell In[30], line 1
#     Here's what we can interpret from this data:
#         ^
# SyntaxError: unterminated string literal (detected at line 1)
